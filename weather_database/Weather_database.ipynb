# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set or random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 737

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='+ weather_api_key
#city_url = url + '&q=' +

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

 # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current description": weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | panzhihua
# Processing Record 4 of Set 1 | karratha
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | filadelfia
# Processing Record 7 of Set 1 | los llanos de aridane
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | baie-comeau
# Processing Record 21 of Set 1 | itaporanga
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | byron bay
# Processing Record 24 of Set 1 | pano polemidia
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | havoysund
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | sur
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 1 | bathsheba
# Processing Record 32 of Set 1 | tura
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | clyde river
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | tombouctou
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | mahon
# Processing Record 41 of Set 1 | laguna
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | necochea
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | cap-aux-meules
# Processing Record 46 of Set 1 | plettenberg bay
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | arica
# Processing Record 49 of Set 1 | cantanhede
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | vestmanna
# Processing Record 2 of Set 2 | tasiilaq
# Processing Record 3 of Set 2 | anadyr
# Processing Record 4 of Set 2 | fairbanks
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | beira
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | flinders
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | kungurtug
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | mudyuga
# City not found. Skipping...
# Processing Record 18 of Set 2 | bairiki
# Processing Record 19 of Set 2 | grand-lahou
# Processing Record 20 of Set 2 | askarovo
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | ofaqim
# Processing Record 24 of Set 2 | guarapari
# Processing Record 25 of Set 2 | port said
# Processing Record 26 of Set 2 | oeiras do para
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | mahebourg
# Processing Record 30 of Set 2 | palana
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | camara de lobos
# Processing Record 33 of Set 2 | kanniyakumari
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | salalah
# Processing Record 36 of Set 2 | tutoia
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | islamkot
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | gamboma
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | sibolga
# Processing Record 44 of Set 2 | sredniy ikorets
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | ventersburg
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | haines junction
# Processing Record 49 of Set 2 | labuan
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | berlin
# Processing Record 3 of Set 3 | rio grande
# Processing Record 4 of Set 3 | mangrol
# Processing Record 5 of Set 3 | staryy nadym
# Processing Record 6 of Set 3 | kalmunai
# Processing Record 7 of Set 3 | geraldton
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | tuktoyaktuk
# Processing Record 10 of Set 3 | chicama
# Processing Record 11 of Set 3 | naryan-mar
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | piacabucu
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | flores
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | nome
# Processing Record 18 of Set 3 | ulladulla
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | stabat
# Processing Record 21 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 3 | oranjemund
# Processing Record 25 of Set 3 | gwembe
# Processing Record 26 of Set 3 | ferrol
# Processing Record 27 of Set 3 | noumea
# Processing Record 28 of Set 3 | virden
# Processing Record 29 of Set 3 | alghero
# Processing Record 30 of Set 3 | lompoc
# Processing Record 31 of Set 3 | abonnema
# Processing Record 32 of Set 3 | georgetown
# Processing Record 33 of Set 3 | trairi
# Processing Record 34 of Set 3 | fuerte olimpo
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | nizhneye kazanishche
# Processing Record 38 of Set 3 | macamic
# Processing Record 39 of Set 3 | kentville
# Processing Record 40 of Set 3 | gizo
# Processing Record 41 of Set 3 | muscat
# Processing Record 42 of Set 3 | maraba
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | anchorage
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | saint-philippe
# Processing Record 48 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 49 of Set 3 | luanda
# Processing Record 50 of Set 3 | dingle
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | kirakira
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | bubaque
# Processing Record 5 of Set 4 | kemin
# Processing Record 6 of Set 4 | dauphin
# Processing Record 7 of Set 4 | cidreira
# Processing Record 8 of Set 4 | komsomolskiy
# Processing Record 9 of Set 4 | impfondo
# Processing Record 10 of Set 4 | zlobin
# Processing Record 11 of Set 4 | upernavik
# Processing Record 12 of Set 4 | santa cruz de tenerife
# Processing Record 13 of Set 4 | natitingou
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | ranong
# Processing Record 17 of Set 4 | mahuva
# Processing Record 18 of Set 4 | new amsterdam
# Processing Record 19 of Set 4 | duz
# City not found. Skipping...
# Processing Record 20 of Set 4 | dhar
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | tirumakudal narsipur
# Processing Record 23 of Set 4 | nalut
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | le passage
# Processing Record 26 of Set 4 | westport
# Processing Record 27 of Set 4 | palmerston
# Processing Record 28 of Set 4 | roald
# Processing Record 29 of Set 4 | tuatapere
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | egvekinot
# Processing Record 33 of Set 4 | san jeronimo
# Processing Record 34 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 4 | sylvan lake
# Processing Record 36 of Set 4 | balabac
# Processing Record 37 of Set 4 | adelaide
# Processing Record 38 of Set 4 | kuytun
# Processing Record 39 of Set 4 | khudumelapye
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | chancay
# Processing Record 42 of Set 4 | payo
# Processing Record 43 of Set 4 | verkhovazhye
# Processing Record 44 of Set 4 | srednekolymsk
# Processing Record 45 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 4 | ostrovnoy
# Processing Record 47 of Set 4 | praia da vitoria
# Processing Record 48 of Set 4 | nshamba
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | senneterre
# Processing Record 2 of Set 5 | ponta delgada
# Processing Record 3 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 5 | jalu
# Processing Record 5 of Set 5 | varzea da palma
# Processing Record 6 of Set 5 | chacabuco
# Processing Record 7 of Set 5 | pevek
# Processing Record 8 of Set 5 | faanui
# Processing Record 9 of Set 5 | canton
# Processing Record 10 of Set 5 | birao
# Processing Record 11 of Set 5 | rio gallegos
# Processing Record 12 of Set 5 | kalevala
# Processing Record 13 of Set 5 | santiago del estero
# Processing Record 14 of Set 5 | brokopondo
# Processing Record 15 of Set 5 | amazar
# Processing Record 16 of Set 5 | gat
# Processing Record 17 of Set 5 | inirida
# Processing Record 18 of Set 5 | pisco
# Processing Record 19 of Set 5 | nikel
# Processing Record 20 of Set 5 | hvide sande
# Processing Record 21 of Set 5 | raleigh
# Processing Record 22 of Set 5 | polis
# Processing Record 23 of Set 5 | qaanaaq
# Processing Record 24 of Set 5 | ariquemes
# Processing Record 25 of Set 5 | dunedin
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | grand gaube
# Processing Record 28 of Set 5 | kahului
# Processing Record 29 of Set 5 | ilebo
# Processing Record 30 of Set 5 | rietavas
# Processing Record 31 of Set 5 | kuusamo
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | khapa
# Processing Record 34 of Set 5 | mashhad
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | pitimbu
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | coquimbo
# Processing Record 40 of Set 5 | unity
# Processing Record 41 of Set 5 | auray
# Processing Record 42 of Set 5 | araouane
# Processing Record 43 of Set 5 | cabras
# Processing Record 44 of Set 5 | peniche
# Processing Record 45 of Set 5 | antropovo
# Processing Record 46 of Set 5 | evensk
# Processing Record 47 of Set 5 | okhotsk
# Processing Record 48 of Set 5 | tongling
# Processing Record 49 of Set 5 | portland
# Processing Record 50 of Set 5 | nikolskoye
# Processing Record 1 of Set 6 | malmyzh
# Processing Record 2 of Set 6 | piedras negras
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | puerto penasco
# Processing Record 5 of Set 6 | hambantota
# Processing Record 6 of Set 6 | kigoma
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | bantogon
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | richards bay
# Processing Record 11 of Set 6 | cape town
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | sao jose da coroa grande
# Processing Record 14 of Set 6 | sumbe
# Processing Record 15 of Set 6 | babra
# Processing Record 16 of Set 6 | fort smith
# Processing Record 17 of Set 6 | tabas
# Processing Record 18 of Set 6 | iquitos
# Processing Record 19 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 6 | longyearbyen
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | jiangkou
# Processing Record 23 of Set 6 | kenai
# Processing Record 24 of Set 6 | broome
# Processing Record 25 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 6 | erzin
# Processing Record 27 of Set 6 | camana
# Processing Record 28 of Set 6 | manokwari
# Processing Record 29 of Set 6 | bermeo
# Processing Record 30 of Set 6 | gravdal
# Processing Record 31 of Set 6 | bandarbeyla
# Processing Record 32 of Set 6 | mattru
# Processing Record 33 of Set 6 | kieta
# Processing Record 34 of Set 6 | saint pete beach
# Processing Record 35 of Set 6 | aykhal
# Processing Record 36 of Set 6 | ahipara
# Processing Record 37 of Set 6 | vardo
# Processing Record 38 of Set 6 | lorengau
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | kupino
# Processing Record 41 of Set 6 | sakakah
# Processing Record 42 of Set 6 | auki
# Processing Record 43 of Set 6 | sobolevo
# Processing Record 44 of Set 6 | kurumkan
# Processing Record 45 of Set 6 | bonoua
# Processing Record 46 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 6 | cherskiy
# Processing Record 48 of Set 6 | chuy
# Processing Record 49 of Set 6 | amapa
# Processing Record 50 of Set 6 | mendoza
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | puerto escondido
# Processing Record 3 of Set 7 | tyup
# Processing Record 4 of Set 7 | zhanaozen
# Processing Record 5 of Set 7 | eureka
# Processing Record 6 of Set 7 | poum
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | kichera
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | rawson
# Processing Record 11 of Set 7 | tiznit
# Processing Record 12 of Set 7 | tynda
# Processing Record 13 of Set 7 | ngaoundere
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | gabriel leyva solano
# Processing Record 16 of Set 7 | magugu
# Processing Record 17 of Set 7 | sorong
# Processing Record 18 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 19 of Set 7 | saint-georges
# Processing Record 20 of Set 7 | san vicente
# Processing Record 21 of Set 7 | snyder
# Processing Record 22 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 7 | khilok
# Processing Record 24 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 7 | khatanga
# Processing Record 26 of Set 7 | mawlaik
# Processing Record 27 of Set 7 | ust-nera
# Processing Record 28 of Set 7 | galle
# Processing Record 29 of Set 7 | sitka
# Processing Record 30 of Set 7 | timra
# Processing Record 31 of Set 7 | novoagansk
# Processing Record 32 of Set 7 | bonavista
# Processing Record 33 of Set 7 | yangjiang
# Processing Record 34 of Set 7 | nanortalik
# Processing Record 35 of Set 7 | falun
# Processing Record 36 of Set 7 | canto do buriti
# Processing Record 37 of Set 7 | torbay
# Processing Record 38 of Set 7 | northam
# Processing Record 39 of Set 7 | yaan
# Processing Record 40 of Set 7 | dickinson
# Processing Record 41 of Set 7 | dubbo
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | dalbandin
# Processing Record 44 of Set 7 | salinopolis
# Processing Record 45 of Set 7 | fochabers
# Processing Record 46 of Set 7 | buala
# Processing Record 47 of Set 7 | falkoping
# City not found. Skipping...
# Processing Record 48 of Set 7 | chuguyevka
# Processing Record 49 of Set 7 | glenwood springs
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | ratnagiri
# Processing Record 2 of Set 8 | la palma
# Processing Record 3 of Set 8 | arman
# Processing Record 4 of Set 8 | parkes
# Processing Record 5 of Set 8 | marsh harbour
# Processing Record 6 of Set 8 | amahai
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 8 | rudbar
# Processing Record 10 of Set 8 | nouadhibou
# Processing Record 11 of Set 8 | otavi
# Processing Record 12 of Set 8 | beacon
# Processing Record 13 of Set 8 | port blair
# Processing Record 14 of Set 8 | muros
# Processing Record 15 of Set 8 | aksarka
# Processing Record 16 of Set 8 | ossora
# Processing Record 17 of Set 8 | naze
# Processing Record 18 of Set 8 | hami
# Processing Record 19 of Set 8 | san patricio
# Processing Record 20 of Set 8 | hargeysa
# Processing Record 21 of Set 8 | baykit
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | north bend
# Processing Record 24 of Set 8 | serenje
# Processing Record 25 of Set 8 | zhenlai
# Processing Record 26 of Set 8 | puerto madero
# Processing Record 27 of Set 8 | shellbrook
# Processing Record 28 of Set 8 | buraydah
# Processing Record 29 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | ilo
# Processing Record 33 of Set 8 | matara
# Processing Record 34 of Set 8 | mahibadhoo
# Processing Record 35 of Set 8 | isangel
# Processing Record 36 of Set 8 | novocheboksarsk
# Processing Record 37 of Set 8 | llano de piedra
# Processing Record 38 of Set 8 | morant bay
# Processing Record 39 of Set 8 | rocha
# Processing Record 40 of Set 8 | latung
# Processing Record 41 of Set 8 | bambanglipuro
# Processing Record 42 of Set 8 | kibre mengist
# Processing Record 43 of Set 8 | katangli
# Processing Record 44 of Set 8 | katsuura
# Processing Record 45 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 8 | yabelo
# Processing Record 47 of Set 8 | cockburn town
# Processing Record 48 of Set 8 | tautira
# Processing Record 49 of Set 8 | faya
# Processing Record 50 of Set 8 | viru
# Processing Record 1 of Set 9 | kilindoni
# Processing Record 2 of Set 9 | ingham
# Processing Record 3 of Set 9 | tomatlan
# Processing Record 4 of Set 9 | magadan
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | hervey bay
# Processing Record 7 of Set 9 | nizhniy kuranakh
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | chabahar
# Processing Record 10 of Set 9 | saint-augustin
# Processing Record 11 of Set 9 | wewak
# Processing Record 12 of Set 9 | nsanje
# Processing Record 13 of Set 9 | prince george
# Processing Record 14 of Set 9 | talcahuano
# Processing Record 15 of Set 9 | bilma
# Processing Record 16 of Set 9 | tvoroyri
# Processing Record 17 of Set 9 | pokrovskoye
# Processing Record 18 of Set 9 | stoenesti
# Processing Record 19 of Set 9 | pauini
# Processing Record 20 of Set 9 | port hawkesbury
# Processing Record 21 of Set 9 | nayoro
# Processing Record 22 of Set 9 | aswan
# Processing Record 23 of Set 9 | tieling
# Processing Record 24 of Set 9 | wagar
# Processing Record 25 of Set 9 | broken hill
# Processing Record 26 of Set 9 | pemangkat
# Processing Record 27 of Set 9 | rakvere
# Processing Record 28 of Set 9 | great bend
# Processing Record 29 of Set 9 | gagnoa
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | muroto
# Processing Record 32 of Set 9 | lamu
# Processing Record 33 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 9 | mezen
# Processing Record 35 of Set 9 | chirongui
# Processing Record 36 of Set 9 | pavlovka
# Processing Record 37 of Set 9 | pasni
# Processing Record 38 of Set 9 | pacific grove
# Processing Record 39 of Set 9 | praia
# Processing Record 40 of Set 9 | nador
# Processing Record 41 of Set 9 | tefe
# Processing Record 42 of Set 9 | oktyabrskoye
# Processing Record 43 of Set 9 | bashtanka
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | camabatela
# Processing Record 46 of Set 9 | atambua
# Processing Record 47 of Set 9 | chingirlau
# Processing Record 48 of Set 9 | kabarnet
# Processing Record 49 of Set 9 | abbeville
# Processing Record 50 of Set 9 | abha
# Processing Record 1 of Set 10 | oregon city
# Processing Record 2 of Set 10 | danlugan
# Processing Record 3 of Set 10 | bandar-e lengeh
# Processing Record 4 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 10 | barda
# Processing Record 6 of Set 10 | manggar
# Processing Record 7 of Set 10 | lavrentiya
# Processing Record 8 of Set 10 | portel
# Processing Record 9 of Set 10 | salta
# Processing Record 10 of Set 10 | kenilworth
# Processing Record 11 of Set 10 | rawlins
# Processing Record 12 of Set 10 | half moon bay
# Processing Record 13 of Set 10 | tambura
# Processing Record 14 of Set 10 | palu
# Processing Record 15 of Set 10 | maryville
# Processing Record 16 of Set 10 | tingo maria
# Processing Record 17 of Set 10 | hovd
# Processing Record 18 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 20 of Set 10 | constitucion
# Processing Record 21 of Set 10 | hurricane
# Processing Record 22 of Set 10 | phalaborwa
# Processing Record 23 of Set 10 | carmen
# Processing Record 24 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 10 | ziniare
# Processing Record 26 of Set 10 | bataipora
# Processing Record 27 of Set 10 | ayr
# Processing Record 28 of Set 10 | talnakh
# Processing Record 29 of Set 10 | leningradskiy
# Processing Record 30 of Set 10 | comodoro rivadavia
# Processing Record 31 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 10 | braco do norte
# Processing Record 33 of Set 10 | vila
# Processing Record 34 of Set 10 | kargil
# Processing Record 35 of Set 10 | chipata
# Processing Record 36 of Set 10 | marawi
# Processing Record 37 of Set 10 | port lincoln
# Processing Record 38 of Set 10 | caluquembe
# Processing Record 39 of Set 10 | natal
# Processing Record 40 of Set 10 | nacala
# Processing Record 41 of Set 10 | abalak
# Processing Record 42 of Set 10 | porto novo
# Processing Record 43 of Set 10 | tamuin
# Processing Record 44 of Set 10 | molina
# Processing Record 45 of Set 10 | raudeberg
# Processing Record 46 of Set 10 | yellapur
# Processing Record 47 of Set 10 | sinnamary
# Processing Record 48 of Set 10 | lazaro cardenas
# Processing Record 49 of Set 10 | kribi
# Processing Record 50 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 1 of Set 11 | deputatskiy
# Processing Record 2 of Set 11 | pointe michel
# Processing Record 3 of Set 11 | snezhnogorsk
# Processing Record 4 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 11 | naberera
# Processing Record 6 of Set 11 | tumsar
# Processing Record 7 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 11 | acapulco
# Processing Record 9 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 11 | goleniow
# Processing Record 12 of Set 11 | nchelenge
# Processing Record 13 of Set 11 | yankton
# Processing Record 14 of Set 11 | batagay-alyta
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | kamien pomorski
# Processing Record 17 of Set 11 | aksu
# Processing Record 18 of Set 11 | pokhara
# Processing Record 19 of Set 11 | tagusao
# Processing Record 20 of Set 11 | ambulu
# Processing Record 21 of Set 11 | kingman
# Processing Record 22 of Set 11 | flin flon
# Processing Record 23 of Set 11 | bucerias
# Processing Record 24 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | grindavik
# Processing Record 26 of Set 11 | staraya mayna
# Processing Record 27 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 11 | naliya
# Processing Record 29 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 30 of Set 11 | ozinki
# Processing Record 31 of Set 11 | sandwick
# Processing Record 32 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 11 | presque isle
# Processing Record 34 of Set 11 | middelburg
# Processing Record 35 of Set 11 | beyla
# Processing Record 36 of Set 11 | meybod
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | nantucket
# Processing Record 39 of Set 11 | porto belo
# Processing Record 40 of Set 11 | ontario
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | avera
# Processing Record 43 of Set 11 | bereda
# Processing Record 44 of Set 11 | castanas
# Processing Record 45 of Set 11 | pokanayevka
# City not found. Skipping...
# Processing Record 46 of Set 11 | imbituba
# Processing Record 47 of Set 11 | lakes entrance
# Processing Record 48 of Set 11 | coruripe
# Processing Record 49 of Set 11 | sovetskiy
# Processing Record 50 of Set 11 | tilichiki
# Processing Record 1 of Set 12 | baoding
# Processing Record 2 of Set 12 | verkhnyaya inta
# Processing Record 3 of Set 12 | kurmanayevka
# Processing Record 4 of Set 12 | thornhill
# Processing Record 5 of Set 12 | kavaratti
# Processing Record 6 of Set 12 | alta floresta
# Processing Record 7 of Set 12 | morropon
# Processing Record 8 of Set 12 | berbera
# Processing Record 9 of Set 12 | sertania
# Processing Record 10 of Set 12 | viedma
# Processing Record 11 of Set 12 | lufilufi
# Processing Record 12 of Set 12 | atasu
# Processing Record 13 of Set 12 | burns lake
# Processing Record 14 of Set 12 | ransang
# Processing Record 15 of Set 12 | glenluce
# Processing Record 16 of Set 12 | seoul
# Processing Record 17 of Set 12 | krasnoselkup
# Processing Record 18 of Set 12 | sangar
# Processing Record 19 of Set 12 | kindu
# Processing Record 20 of Set 12 | gresham
# Processing Record 21 of Set 12 | lethem
# Processing Record 22 of Set 12 | tucuma
# Processing Record 23 of Set 12 | saint-francois
# Processing Record 24 of Set 12 | kabin buri
# Processing Record 25 of Set 12 | hay river
# Processing Record 26 of Set 12 | port augusta
# Processing Record 27 of Set 12 | san ramon de la nueva oran
# Processing Record 28 of Set 12 | pacifica
# Processing Record 29 of Set 12 | la vega
# Processing Record 30 of Set 12 | ixtapa
# Processing Record 31 of Set 12 | samarai
# Processing Record 32 of Set 12 | celestun
# Processing Record 33 of Set 12 | the valley
# Processing Record 34 of Set 12 | mana
# Processing Record 35 of Set 12 | buchanan
# Processing Record 36 of Set 12 | padang
# Processing Record 37 of Set 12 | lensk
# Processing Record 38 of Set 12 | qasigiannguit
# Processing Record 39 of Set 12 | kangaatsiaq
# Processing Record 40 of Set 12 | ballina
# Processing Record 41 of Set 12 | wuchang
# Processing Record 42 of Set 12 | alice springs
# Processing Record 43 of Set 12 | paramonga
# Processing Record 44 of Set 12 | barranca
# Processing Record 45 of Set 12 | borogontsy
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | lolodorf
# Processing Record 48 of Set 12 | truckee
# Processing Record 49 of Set 12 | tarakan
# Processing Record 50 of Set 12 | ginir
# Processing Record 1 of Set 13 | bowen
# Processing Record 2 of Set 13 | kalmar
# Processing Record 3 of Set 13 | adrar
# Processing Record 4 of Set 13 | ararat
# Processing Record 5 of Set 13 | douglas
# Processing Record 6 of Set 13 | leh
# Processing Record 7 of Set 13 | kailua
# Processing Record 8 of Set 13 | monroe
# Processing Record 9 of Set 13 | langres
# Processing Record 10 of Set 13 | takoradi
# Processing Record 11 of Set 13 | tamandare
# Processing Record 12 of Set 13 | miri
# Processing Record 13 of Set 13 | tuzha
# Processing Record 14 of Set 13 | sosva
# Processing Record 15 of Set 13 | middelfart
# Processing Record 16 of Set 13 | neiafu
# Processing Record 17 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 18 of Set 13 | chimbote
# Processing Record 19 of Set 13 | severo-kurilsk
# Processing Record 20 of Set 13 | borujan
# City not found. Skipping...
# Processing Record 21 of Set 13 | san buenaventura
# Processing Record 22 of Set 13 | lenzing
# Processing Record 23 of Set 13 | kuala sungai baru
# Processing Record 24 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 13 | itapirapua
# Processing Record 26 of Set 13 | pucallpa
# Processing Record 27 of Set 13 | chernaya kholunitsa
# Processing Record 28 of Set 13 | jacareacanga
# Processing Record 29 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 13 | gua musang
# Processing Record 32 of Set 13 | stokmarknes
# Processing Record 33 of Set 13 | taoudenni
# Processing Record 34 of Set 13 | miyang
# Processing Record 35 of Set 13 | strezhevoy
# Processing Record 36 of Set 13 | tezu
# Processing Record 37 of Set 13 | turayf
# Processing Record 38 of Set 13 | acarau
# Processing Record 39 of Set 13 | labrea
# Processing Record 40 of Set 13 | saint-raymond
# Processing Record 41 of Set 13 | seminole
# Processing Record 42 of Set 13 | baymak
# Processing Record 43 of Set 13 | port pirie
# Processing Record 44 of Set 13 | vaitape
# Processing Record 45 of Set 13 | kloulklubed
# Processing Record 46 of Set 13 | novobirilyussy
# Processing Record 47 of Set 13 | kawalu
# Processing Record 48 of Set 13 | port-gentil
# Processing Record 49 of Set 13 | sakyla
# Processing Record 50 of Set 13 | tucuman
# Processing Record 1 of Set 14 | honiara
# Processing Record 2 of Set 14 | harper
# Processing Record 3 of Set 14 | motril
# Processing Record 4 of Set 14 | marsaxlokk
# Processing Record 5 of Set 14 | atar
# Processing Record 6 of Set 14 | rabo de peixe
# Processing Record 7 of Set 14 | storm lake
# Processing Record 8 of Set 14 | inhambane
# Processing Record 9 of Set 14 | lakselv
# Processing Record 10 of Set 14 | panlaitan
# Processing Record 11 of Set 14 | shihezi
# Processing Record 12 of Set 14 | nioki
# Processing Record 13 of Set 14 | sola
# Processing Record 14 of Set 14 | kimbe
# Processing Record 15 of Set 14 | khandbari
# Processing Record 16 of Set 14 | vila franca do campo
# Processing Record 17 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 14 | andenes
# Processing Record 19 of Set 14 | beckley
# Processing Record 20 of Set 14 | boende
# Processing Record 21 of Set 14 | lincoln
# Processing Record 22 of Set 14 | rafaela
# Processing Record 23 of Set 14 | kismayo
# Processing Record 24 of Set 14 | port townsend
# Processing Record 25 of Set 14 | baft
# Processing Record 26 of Set 14 | sweetwater
# Processing Record 27 of Set 14 | pringsewu
# Processing Record 28 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 14 | port shepstone
# Processing Record 30 of Set 14 | sharan
# Processing Record 31 of Set 14 | sri aman
# Processing Record 32 of Set 14 | del rio
# Processing Record 33 of Set 14 | prokopyevsk
# Processing Record 34 of Set 14 | yorosso
# Processing Record 35 of Set 14 | falkenberg
# Processing Record 36 of Set 14 | nurota
# Processing Record 37 of Set 14 | pimentel
# Processing Record 38 of Set 14 | lubumbashi
# Processing Record 39 of Set 14 | carballo
# Processing Record 40 of Set 14 | itaueira
# Processing Record 41 of Set 14 | ouesso
# Processing Record 42 of Set 14 | liverpool
# Processing Record 43 of Set 14 | sorland
# Processing Record 44 of Set 14 | montepuez
# Processing Record 45 of Set 14 | puerto concordia
# Processing Record 46 of Set 14 | petatlan
# Processing Record 47 of Set 14 | chikwawa
# Processing Record 48 of Set 14 | japura
# Processing Record 49 of Set 14 | agirish
# Processing Record 50 of Set 14 | meulaboh
# Processing Record 1 of Set 15 | fare
# Processing Record 2 of Set 15 | aqtobe
# Processing Record 3 of Set 15 | tirlyanskiy
# Processing Record 4 of Set 15 | ouallam
# Processing Record 5 of Set 15 | makakilo city
# Processing Record 6 of Set 15 | gushikawa
# Processing Record 7 of Set 15 | inuvik
# Processing Record 8 of Set 15 | rybnoye
# Processing Record 9 of Set 15 | lerwick
# Processing Record 10 of Set 15 | umm lajj
# Processing Record 11 of Set 15 | san isidro
# Processing Record 12 of Set 15 | rio branco
# Processing Record 13 of Set 15 | progreso
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | san andres
# Processing Record 16 of Set 15 | santa cruz
# Processing Record 17 of Set 15 | oussouye
# Processing Record 18 of Set 15 | ngara
# Processing Record 19 of Set 15 | kashi
# Processing Record 20 of Set 15 | hamilton
# Processing Record 21 of Set 15 | xixiang
# Processing Record 22 of Set 15 | kurilsk
# Processing Record 23 of Set 15 | aleksandrovka
# Processing Record 24 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 15 | nadym
# Processing Record 26 of Set 15 | dicabisagan
# Processing Record 27 of Set 15 | mersing
# Processing Record 28 of Set 15 | hurghada
# Processing Record 29 of Set 15 | parana
# Processing Record 30 of Set 15 | obluche
# City not found. Skipping...
# Processing Record 31 of Set 15 | presidencia roque saenz pena
# Processing Record 32 of Set 15 | launceston
# Processing Record 33 of Set 15 | khandyga
# Processing Record 34 of Set 15 | fowa
# Processing Record 35 of Set 15 | paamiut
# Processing Record 36 of Set 15 | pirapo
# Processing Record 37 of Set 15 | maldonado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Jamestown  42.0970  -79.2353     38.52        55           0
# 1            Yellowknife  62.4560 -114.3525     -2.58        90         100
# 2              Panzhihua  26.5851  101.7128     46.33        63           0
# 3               Karratha -20.7377  116.8463     80.29        67          96
# 4                 Kodiak  57.7900 -152.4072     26.11        74         100
# 5             Filadelfia  39.9523  -75.1638     37.76        91         100
# 6  Los Llanos De Aridane  28.6585  -17.9182     64.15        77          40
# 7                 Avarua -21.2078 -159.7750     78.85        83          40
# 8           Punta Arenas -53.1500  -70.9167     60.82        87         100
# 9                  Kapaa  22.0752 -159.3190     73.72        74          75
#
#    Wind Speed Country Current description
# 0       12.66      US           clear sky
# 1       13.80      CA          light snow
# 2        1.12      CN           clear sky
# 3       17.20      AU     overcast clouds
# 4        4.61      US     overcast clouds
# 5        3.00      US                mist
# 6       14.97      ES    scattered clouds
# 7       17.27      CK    scattered clouds
# 8        5.75      CL          light rain
# 9       14.97      US       broken clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Jamestown      US  42.0970  -79.2353     38.52        55
# 1            Yellowknife      CA  62.4560 -114.3525     -2.58        90
# 2              Panzhihua      CN  26.5851  101.7128     46.33        63
# 3               Karratha      AU -20.7377  116.8463     80.29        67
# 4                 Kodiak      US  57.7900 -152.4072     26.11        74
# 5             Filadelfia      US  39.9523  -75.1638     37.76        91
# 6  Los Llanos De Aridane      ES  28.6585  -17.9182     64.15        77
# 7                 Avarua      CK -21.2078 -159.7750     78.85        83
# 8           Punta Arenas      CL -53.1500  -70.9167     60.82        87
# 9                  Kapaa      US  22.0752 -159.3190     73.72        74
#
#    Cloudiness  Wind Speed Current description
# 0           0       12.66           clear sky
# 1         100       13.80          light snow
# 2           0        1.12           clear sky
# 3          96       17.20     overcast clouds
# 4         100        4.61     overcast clouds
# 5         100        3.00                mist
# 6          40       14.97    scattered clouds
# 7          40       17.27    scattered clouds
# 8         100        5.75          light rain
# 9          75       14.97       broken clouds

# %%
#Create the output file (CSV)
output_data_file = 'weatherpy_database.csv'
#Export the City_data into a csv
city_data_df.to_csv(output_data_file, index_label='City_ID')

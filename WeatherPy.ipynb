# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set or random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 617

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID='+ weather_api_key
#city_url = url + '&q=' +

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

 # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | tasiilaq
# Processing Record 4 of Set 1 | llanes
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | palu
# Processing Record 7 of Set 1 | port macquarie
# Processing Record 8 of Set 1 | tigil
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | qinzhou
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | turgoyak
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | vila velha
# Processing Record 24 of Set 1 | norsup
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | alice springs
# Processing Record 29 of Set 1 | pudem
# Processing Record 30 of Set 1 | ureshino
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | richards bay
# Processing Record 34 of Set 1 | brae
# Processing Record 35 of Set 1 | birao
# Processing Record 36 of Set 1 | semey
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | komsomolskiy
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | harboore
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | fukue
# Processing Record 46 of Set 1 | elko
# Processing Record 47 of Set 1 | bathurst
# Processing Record 48 of Set 1 | puro
# Processing Record 49 of Set 1 | inverell
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | ketchikan
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | touros
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | buchanan
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 15 of Set 2 | lorengau
# Processing Record 16 of Set 2 | koutiala
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | waipawa
# Processing Record 20 of Set 2 | roald
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | pandan niog
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | ledyard
# Processing Record 25 of Set 2 | lompoc
# Processing Record 26 of Set 2 | sikonge
# Processing Record 27 of Set 2 | shubarkuduk
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 2 | broome
# Processing Record 31 of Set 2 | codrington
# Processing Record 32 of Set 2 | yulara
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 2 | vila do maio
# Processing Record 36 of Set 2 | sao joao da barra
# Processing Record 37 of Set 2 | bubaque
# Processing Record 38 of Set 2 | kashan
# Processing Record 39 of Set 2 | prince rupert
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | rawson
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | santona
# Processing Record 44 of Set 2 | mitu
# Processing Record 45 of Set 2 | omboue
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | aksu
# Processing Record 48 of Set 2 | la rioja
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | vrangel
# Processing Record 1 of Set 3 | torre annunziata
# Processing Record 2 of Set 3 | sur
# Processing Record 3 of Set 3 | tambacounda
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | vestmannaeyjar
# Processing Record 6 of Set 3 | makokou
# Processing Record 7 of Set 3 | isangel
# Processing Record 8 of Set 3 | sakakah
# Processing Record 9 of Set 3 | quirinopolis
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | norman wells
# Processing Record 14 of Set 3 | acarau
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | leningradskiy
# Processing Record 17 of Set 3 | puerto del rosario
# Processing Record 18 of Set 3 | diamantino
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | dourbali
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | raudeberg
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | alamosa
# Processing Record 25 of Set 3 | kuvshinovo
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | takaka
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | jaciara
# Processing Record 30 of Set 3 | ploemeur
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | pangnirtung
# Processing Record 33 of Set 3 | rocha
# Processing Record 34 of Set 3 | agapovka
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | saint-joseph
# Processing Record 41 of Set 3 | biak
# Processing Record 42 of Set 3 | bryanka
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | barbastro
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | chokurdakh
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | pokhara
# Processing Record 50 of Set 3 | roccastrada
# Processing Record 1 of Set 4 | mahebourg
# Processing Record 2 of Set 4 | fortuna
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | coahuayana
# Processing Record 5 of Set 4 | constitucion
# Processing Record 6 of Set 4 | burica
# City not found. Skipping...
# Processing Record 7 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 4 | atambua
# Processing Record 9 of Set 4 | kirkwall
# Processing Record 10 of Set 4 | saskylakh
# Processing Record 11 of Set 4 | moroto
# Processing Record 12 of Set 4 | poum
# Processing Record 13 of Set 4 | oranjemund
# Processing Record 14 of Set 4 | rodrigues alves
# Processing Record 15 of Set 4 | andenes
# Processing Record 16 of Set 4 | lesozavodsk
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | bathsheba
# Processing Record 19 of Set 4 | lamar
# Processing Record 20 of Set 4 | aleksandrov gay
# Processing Record 21 of Set 4 | los llanos de aridane
# Processing Record 22 of Set 4 | malanje
# Processing Record 23 of Set 4 | dharchula
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | barcelos
# Processing Record 26 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | gayeri
# Processing Record 29 of Set 4 | rock springs
# Processing Record 30 of Set 4 | vung tau
# Processing Record 31 of Set 4 | safaga
# Processing Record 32 of Set 4 | vao
# Processing Record 33 of Set 4 | bud
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | odweyne
# Processing Record 36 of Set 4 | puerto escondido
# Processing Record 37 of Set 4 | tateyama
# Processing Record 38 of Set 4 | nhulunbuy
# Processing Record 39 of Set 4 | sept-iles
# Processing Record 40 of Set 4 | tiksi
# Processing Record 41 of Set 4 | bindi
# Processing Record 42 of Set 4 | requena
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | qui nhon
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | nanortalik
# Processing Record 47 of Set 4 | coquimbo
# Processing Record 48 of Set 4 | rorvik
# Processing Record 49 of Set 4 | ostrovnoy
# Processing Record 50 of Set 4 | reconquista
# Processing Record 1 of Set 5 | beringovskiy
# Processing Record 2 of Set 5 | corinto
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | wembley
# Processing Record 5 of Set 5 | burnie
# Processing Record 6 of Set 5 | dodge city
# Processing Record 7 of Set 5 | clarksdale
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | tingi
# Processing Record 10 of Set 5 | kokopo
# Processing Record 11 of Set 5 | robertsport
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | filingue
# Processing Record 14 of Set 5 | nogales
# Processing Record 15 of Set 5 | jimenez
# Processing Record 16 of Set 5 | kieta
# Processing Record 17 of Set 5 | kenai
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | clyde river
# Processing Record 20 of Set 5 | sorkjosen
# Processing Record 21 of Set 5 | boueni
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | beira
# Processing Record 24 of Set 5 | sterling
# Processing Record 25 of Set 5 | guadalupe victoria
# Processing Record 26 of Set 5 | banjar
# Processing Record 27 of Set 5 | najran
# Processing Record 28 of Set 5 | pozo colorado
# Processing Record 29 of Set 5 | sinjar
# Processing Record 30 of Set 5 | hamilton
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | kayes
# Processing Record 33 of Set 5 | vardo
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | green river
# Processing Record 36 of Set 5 | pombas
# Processing Record 37 of Set 5 | berlevag
# Processing Record 38 of Set 5 | puerto ayora
# Processing Record 39 of Set 5 | tual
# Processing Record 40 of Set 5 | suluq
# Processing Record 41 of Set 5 | asau
# Processing Record 42 of Set 5 | kilindoni
# Processing Record 43 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 5 | hualmay
# Processing Record 45 of Set 5 | nargana
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | lubango
# Processing Record 48 of Set 5 | tongliao
# Processing Record 49 of Set 5 | bairiki
# Processing Record 50 of Set 5 | kodinsk
# Processing Record 1 of Set 6 | taksimo
# Processing Record 2 of Set 6 | saint george
# Processing Record 3 of Set 6 | san andres
# Processing Record 4 of Set 6 | hirschaid
# Processing Record 5 of Set 6 | aasiaat
# Processing Record 6 of Set 6 | khandagayty
# Processing Record 7 of Set 6 | jinsha
# Processing Record 8 of Set 6 | wattegama
# Processing Record 9 of Set 6 | aykino
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | masuguru
# Processing Record 12 of Set 6 | caravelas
# Processing Record 13 of Set 6 | sarti
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | saint-augustin
# Processing Record 16 of Set 6 | luanda
# Processing Record 17 of Set 6 | tezu
# Processing Record 18 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 6 | roma
# Processing Record 22 of Set 6 | kavieng
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | port lincoln
# Processing Record 25 of Set 6 | mehamn
# Processing Record 26 of Set 6 | itarema
# Processing Record 27 of Set 6 | qidong
# Processing Record 28 of Set 6 | escanaba
# Processing Record 29 of Set 6 | adrar
# Processing Record 30 of Set 6 | tiznit
# Processing Record 31 of Set 6 | pathein
# Processing Record 32 of Set 6 | hirara
# Processing Record 33 of Set 6 | kargopol
# Processing Record 34 of Set 6 | caala
# Processing Record 35 of Set 6 | svetlyy yar
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | ugoofaaru
# Processing Record 38 of Set 6 | itainopolis
# Processing Record 39 of Set 6 | kapuskasing
# Processing Record 40 of Set 6 | hinton
# Processing Record 41 of Set 6 | bozeman
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | mayo
# Processing Record 44 of Set 6 | katsuura
# Processing Record 45 of Set 6 | sandakan
# Processing Record 46 of Set 6 | vera cruz
# Processing Record 47 of Set 6 | margate
# Processing Record 48 of Set 6 | flinders
# Processing Record 49 of Set 6 | algarrobo
# Processing Record 50 of Set 6 | areka
# Processing Record 1 of Set 7 | alegrete
# Processing Record 2 of Set 7 | amposta
# Processing Record 3 of Set 7 | dickinson
# Processing Record 4 of Set 7 | kalmar
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | tuktoyaktuk
# Processing Record 7 of Set 7 | coihaique
# Processing Record 8 of Set 7 | karratha
# Processing Record 9 of Set 7 | ahipara
# Processing Record 10 of Set 7 | sabha
# Processing Record 11 of Set 7 | northam
# Processing Record 12 of Set 7 | opuwo
# Processing Record 13 of Set 7 | winchester
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | makakilo city
# Processing Record 16 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 17 of Set 7 | louisville
# Processing Record 18 of Set 7 | vila franca do campo
# Processing Record 19 of Set 7 | mocuba
# Processing Record 20 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 7 | kigoma
# Processing Record 22 of Set 7 | marathopolis
# City not found. Skipping...
# Processing Record 23 of Set 7 | yumen
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | sola
# Processing Record 26 of Set 7 | tuatapere
# Processing Record 27 of Set 7 | de-kastri
# Processing Record 28 of Set 7 | igbo ora
# Processing Record 29 of Set 7 | morondava
# Processing Record 30 of Set 7 | pont-rouge
# Processing Record 31 of Set 7 | kutum
# Processing Record 32 of Set 7 | zeya
# Processing Record 33 of Set 7 | eirunepe
# Processing Record 34 of Set 7 | rubio
# Processing Record 35 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 7 | guipavas
# Processing Record 37 of Set 7 | devils lake
# Processing Record 38 of Set 7 | zyryanka
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | dongying
# Processing Record 41 of Set 7 | tukrah
# Processing Record 42 of Set 7 | olafsvik
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | te anau
# Processing Record 45 of Set 7 | tuy hoa
# Processing Record 46 of Set 7 | asfi
# Processing Record 47 of Set 7 | nalut
# Processing Record 48 of Set 7 | iqaluit
# Processing Record 49 of Set 7 | pandan
# Processing Record 50 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | kiruna
# Processing Record 3 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 8 | zehdenick
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | kloulklubed
# Processing Record 7 of Set 8 | moranbah
# Processing Record 8 of Set 8 | payakumbuh
# Processing Record 9 of Set 8 | ivanivka
# Processing Record 10 of Set 8 | mugango
# Processing Record 11 of Set 8 | juneau
# Processing Record 12 of Set 8 | thinadhoo
# Processing Record 13 of Set 8 | saint-georges
# Processing Record 14 of Set 8 | helong
# Processing Record 15 of Set 8 | guaruja
# Processing Record 16 of Set 8 | arandis
# Processing Record 17 of Set 8 | brus laguna
# Processing Record 18 of Set 8 | samarai
# Processing Record 19 of Set 8 | mmabatho
# Processing Record 20 of Set 8 | namibe
# Processing Record 21 of Set 8 | marevo
# Processing Record 22 of Set 8 | christchurch
# Processing Record 23 of Set 8 | manadhoo
# Processing Record 24 of Set 8 | carballo
# Processing Record 25 of Set 8 | qasigiannguit
# Processing Record 26 of Set 8 | surt
# Processing Record 27 of Set 8 | nagornskiy
# Processing Record 28 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 8 | emerald
# Processing Record 30 of Set 8 | cabedelo
# Processing Record 31 of Set 8 | ribeira brava
# Processing Record 32 of Set 8 | gamba
# Processing Record 33 of Set 8 | kaitangata
# Processing Record 34 of Set 8 | tongzi
# Processing Record 35 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 8 | ghanzi
# Processing Record 37 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 8 | nouadhibou
# Processing Record 39 of Set 8 | piacabucu
# Processing Record 40 of Set 8 | crystal beach
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | saint anthony
# Processing Record 43 of Set 8 | viedma
# Processing Record 44 of Set 8 | baykit
# Processing Record 45 of Set 8 | ambulu
# Processing Record 46 of Set 8 | nurota
# Processing Record 47 of Set 8 | korsakov
# Processing Record 48 of Set 8 | guerrero negro
# Processing Record 49 of Set 8 | lebanon
# Processing Record 50 of Set 8 | dhidhdhoo
# Processing Record 1 of Set 9 | ahwa
# Processing Record 2 of Set 9 | bakel
# Processing Record 3 of Set 9 | dutse
# Processing Record 4 of Set 9 | bambanglipuro
# Processing Record 5 of Set 9 | bonao
# Processing Record 6 of Set 9 | rajshahi
# Processing Record 7 of Set 9 | ternate
# Processing Record 8 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 9 | mattru
# Processing Record 10 of Set 9 | champerico
# Processing Record 11 of Set 9 | znamenskoye
# Processing Record 12 of Set 9 | grindavik
# Processing Record 13 of Set 9 | antalaha
# Processing Record 14 of Set 9 | san policarpo
# Processing Record 15 of Set 9 | katherine
# Processing Record 16 of Set 9 | jiazi
# Processing Record 17 of Set 9 | mutis
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | nemuro
# Processing Record 20 of Set 9 | sabang
# Processing Record 21 of Set 9 | udachnyy
# Processing Record 22 of Set 9 | pochutla
# Processing Record 23 of Set 9 | yokadouma
# Processing Record 24 of Set 9 | cherskiy
# Processing Record 25 of Set 9 | trat
# Processing Record 26 of Set 9 | kaeo
# Processing Record 27 of Set 9 | garowe
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | rupert
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | college
# Processing Record 32 of Set 9 | kudahuvadhoo
# Processing Record 33 of Set 9 | acapulco
# Processing Record 34 of Set 9 | edson
# Processing Record 35 of Set 9 | maniitsoq
# Processing Record 36 of Set 9 | saint-louis
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | muli
# Processing Record 39 of Set 9 | omaruru
# Processing Record 40 of Set 9 | sulechow
# Processing Record 41 of Set 9 | grants
# Processing Record 42 of Set 9 | shieli
# Processing Record 43 of Set 9 | stornoway
# Processing Record 44 of Set 9 | mont-dore
# Processing Record 45 of Set 9 | bilma
# Processing Record 46 of Set 9 | acajutla
# Processing Record 47 of Set 9 | jumla
# Processing Record 48 of Set 9 | dingzhou
# Processing Record 49 of Set 9 | chitral
# Processing Record 50 of Set 9 | chlum u trebone
# Processing Record 1 of Set 10 | abong mbang
# Processing Record 2 of Set 10 | toora-khem
# Processing Record 3 of Set 10 | oistins
# Processing Record 4 of Set 10 | ancud
# Processing Record 5 of Set 10 | iquitos
# Processing Record 6 of Set 10 | bar harbor
# Processing Record 7 of Set 10 | palembang
# Processing Record 8 of Set 10 | beloha
# Processing Record 9 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 10 of Set 10 | tierralta
# Processing Record 11 of Set 10 | misratah
# Processing Record 12 of Set 10 | narasannapeta
# Processing Record 13 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 10 | santiago
# Processing Record 15 of Set 10 | quatre cocos
# Processing Record 16 of Set 10 | tawang
# Processing Record 17 of Set 10 | la ronge
# Processing Record 18 of Set 10 | havoysund
# Processing Record 19 of Set 10 | pringsewu
# Processing Record 20 of Set 10 | goderich
# Processing Record 21 of Set 10 | vagur
# Processing Record 22 of Set 10 | nichinan
# Processing Record 23 of Set 10 | semme
# Processing Record 24 of Set 10 | port-gentil
# Processing Record 25 of Set 10 | baherden
# Processing Record 26 of Set 10 | idaho falls
# Processing Record 27 of Set 10 | riyadh
# Processing Record 28 of Set 10 | virginia beach
# Processing Record 29 of Set 10 | port hardy
# Processing Record 30 of Set 10 | voyvozh
# Processing Record 31 of Set 10 | portland
# Processing Record 32 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 10 | nantucket
# Processing Record 34 of Set 10 | kuandian
# Processing Record 35 of Set 10 | mildura
# Processing Record 36 of Set 10 | okhotsk
# Processing Record 37 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 10 | kota tinggi
# Processing Record 39 of Set 10 | camocim
# Processing Record 40 of Set 10 | imbituba
# Processing Record 41 of Set 10 | yukon
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | unai
# Processing Record 44 of Set 10 | puerto plata
# Processing Record 45 of Set 10 | mananjary
# Processing Record 46 of Set 10 | shimoda
# Processing Record 47 of Set 10 | saint-francois
# Processing Record 48 of Set 10 | ilulissat
# Processing Record 49 of Set 10 | blagoveshchenka
# Processing Record 50 of Set 10 | meyrin
# Processing Record 1 of Set 11 | sambava
# Processing Record 2 of Set 11 | setermoen
# Processing Record 3 of Set 11 | fuerte olimpo
# Processing Record 4 of Set 11 | pucallpa
# Processing Record 5 of Set 11 | homer
# Processing Record 6 of Set 11 | farmos
# Processing Record 7 of Set 11 | waingapu
# Processing Record 8 of Set 11 | sistranda
# Processing Record 9 of Set 11 | hovd
# Processing Record 10 of Set 11 | kijang
# Processing Record 11 of Set 11 | cartagena
# Processing Record 12 of Set 11 | sorland
# Processing Record 13 of Set 11 | varhaug
# Processing Record 14 of Set 11 | korla
# Processing Record 15 of Set 11 | kisangani
# Processing Record 16 of Set 11 | zabol
# Processing Record 17 of Set 11 | san cristobal
# Processing Record 18 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 19 of Set 11 | salinas
# Processing Record 20 of Set 11 | san jeronimo
# Processing Record 21 of Set 11 | ust-kut
# Processing Record 22 of Set 11 | dzaoudzi
# Processing Record 23 of Set 11 | mongoumba
# Processing Record 24 of Set 11 | chapais
# Processing Record 25 of Set 11 | innisfail
# Processing Record 26 of Set 11 | brigantine
# Processing Record 27 of Set 11 | dali
# Processing Record 28 of Set 11 | tabou
# Processing Record 29 of Set 11 | inhambane
# Processing Record 30 of Set 11 | umm kaddadah
# Processing Record 31 of Set 11 | namatanai
# Processing Record 32 of Set 11 | massakory
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | tazmalt
# Processing Record 35 of Set 11 | verkh-tula
# Processing Record 36 of Set 11 | yazman
# Processing Record 37 of Set 11 | marsaxlokk
# Processing Record 38 of Set 11 | camacha
# Processing Record 39 of Set 11 | figeac
# Processing Record 40 of Set 11 | henties bay
# Processing Record 41 of Set 11 | tecoanapa
# Processing Record 42 of Set 11 | praia da vitoria
# Processing Record 43 of Set 11 | marsh harbour
# Processing Record 44 of Set 11 | hambantota
# Processing Record 45 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 46 of Set 11 | fort frances
# Processing Record 47 of Set 11 | lavrentiya
# Processing Record 48 of Set 11 | sao felix do xingu
# Processing Record 49 of Set 11 | vurnary
# Processing Record 50 of Set 11 | pedra branca
# Processing Record 1 of Set 12 | kibiti
# Processing Record 2 of Set 12 | ionia
# Processing Record 3 of Set 12 | gogrial
# Processing Record 4 of Set 12 | rock sound
# Processing Record 5 of Set 12 | morgantown
# Processing Record 6 of Set 12 | vuktyl
# Processing Record 7 of Set 12 | grand gaube
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | umkomaas
# Processing Record 10 of Set 12 | santa barbara
# Processing Record 11 of Set 12 | hermosillo
# Processing Record 12 of Set 12 | tambopata
# Processing Record 13 of Set 12 | praia
# Processing Record 14 of Set 12 | mezhdurechensk
# Processing Record 15 of Set 12 | pangkalanbuun
# Processing Record 16 of Set 12 | balkhash
# Processing Record 17 of Set 12 | kharan
# Processing Record 18 of Set 12 | gympie
# Processing Record 19 of Set 12 | weligama
# Processing Record 20 of Set 12 | karlstadt
# Processing Record 21 of Set 12 | aykhal
# Processing Record 22 of Set 12 | vila
# Processing Record 23 of Set 12 | wanning
# Processing Record 24 of Set 12 | paamiut
# Processing Record 25 of Set 12 | husavik
# Processing Record 26 of Set 12 | bocas del toro
# Processing Record 27 of Set 12 | cozumel
# Processing Record 28 of Set 12 | krasnogvardeyskoye
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | benghazi
# Processing Record 31 of Set 12 | were ilu
# Processing Record 32 of Set 12 | kahului
# Processing Record 33 of Set 12 | vanimo
# Processing Record 34 of Set 12 | port augusta
# Processing Record 35 of Set 12 | de aar
# Processing Record 36 of Set 12 | abha
# Processing Record 37 of Set 12 | bara
# Processing Record 38 of Set 12 | kishi
# Processing Record 39 of Set 12 | mirnyy
# Processing Record 40 of Set 12 | fairbanks
# Processing Record 41 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 12 | oriximina
# Processing Record 43 of Set 12 | skibbereen
# Processing Record 44 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 12 | sharlyk
# Processing Record 46 of Set 12 | lannion
# Processing Record 47 of Set 12 | weinan
# Processing Record 48 of Set 12 | ayan
# Processing Record 49 of Set 12 | san quintin
# Processing Record 50 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 1 of Set 13 | dobeln
# Processing Record 2 of Set 13 | tingrela
# City not found. Skipping...
# Processing Record 3 of Set 13 | manaus
# Processing Record 4 of Set 13 | labis
# Processing Record 5 of Set 13 | karpathos
# Processing Record 6 of Set 13 | mbeya
# Processing Record 7 of Set 13 | nago
# Processing Record 8 of Set 13 | saint-pierre
# Processing Record 9 of Set 13 | providencia
# Processing Record 10 of Set 13 | antsohihy
# Processing Record 11 of Set 13 | shizunai
# Processing Record 12 of Set 13 | saryozek
# Processing Record 13 of Set 13 | quelimane
# Processing Record 14 of Set 13 | kiunga
# Processing Record 15 of Set 13 | ejura
# Processing Record 16 of Set 13 | collie
# Processing Record 17 of Set 13 | ascension
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kapaa  22.0752 -159.3190     71.92        65          20
# 1           Vaini -21.2000 -175.2000     71.76       100          20
# 2        Tasiilaq  65.6145  -37.6368     14.16        58          56
# 3          Llanes  43.4198   -4.7549     54.90        83         100
# 4          Atuona  -9.8000 -139.0333     78.35        70          24
# 5            Palu  -0.8917  119.8707     74.73        95         100
# 6  Port Macquarie -31.4333  152.9167     64.29        94          75
# 7           Tigil  57.8000  158.6667     -1.80        96          31
# 8            Lata  40.1629   -8.3327     55.81        82         100
# 9         Rikitea -23.1203 -134.9692     77.36        77         100
#
#    Wind Speed Country                 Date
# 0       11.50      US  2022-02-03 18:02:50
# 1        2.30      TO  2022-02-03 18:04:50
# 2        7.31      GL  2022-02-03 18:06:32
# 3        1.43      ES  2022-02-03 18:06:33
# 4       17.74      PF  2022-02-03 18:03:03
# 5        1.97      ID  2022-02-03 18:06:34
# 6       12.66      AU  2022-02-03 18:06:34
# 7        2.48      RU  2022-02-03 18:05:26
# 8        3.29      PT  2022-02-03 18:02:16
# 9       14.41      PF  2022-02-03 18:06:35

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0           Kapaa      US  2022-02-03 18:02:50  22.0752 -159.3190     71.92
# 1           Vaini      TO  2022-02-03 18:04:50 -21.2000 -175.2000     71.76
# 2        Tasiilaq      GL  2022-02-03 18:06:32  65.6145  -37.6368     14.16
# 3          Llanes      ES  2022-02-03 18:06:33  43.4198   -4.7549     54.90
# 4          Atuona      PF  2022-02-03 18:03:03  -9.8000 -139.0333     78.35
# 5            Palu      ID  2022-02-03 18:06:34  -0.8917  119.8707     74.73
# 6  Port Macquarie      AU  2022-02-03 18:06:34 -31.4333  152.9167     64.29
# 7           Tigil      RU  2022-02-03 18:05:26  57.8000  158.6667     -1.80
# 8            Lata      PT  2022-02-03 18:02:16  40.1629   -8.3327     55.81
# 9         Rikitea      PF  2022-02-03 18:06:35 -23.1203 -134.9692     77.36
#
#    Humidity  Cloudiness  Wind Speed
# 0        65          20       11.50
# 1       100          20        2.30
# 2        58          56        7.31
# 3        83         100        1.43
# 4        70          24       17.74
# 5        95         100        1.97
# 6        94          75       12.66
# 7        96          31        2.48
# 8        82         100        3.29
# 9        77         100       14.41

# %%
#Create the output file (CSV)
output_data_file = 'weather_data/cities.csv'
#Export the City_data into a csv
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
#Extract relevant fields from the DataFrame for plotting
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
#import time module
import time
#Get today's date in seconds
today = time.time()
today
# Out:
# 1643912587.016224

# %%
today = time.strftime('%x')
today
# Out:
# '02/03/22'

# %%
#Build the scatter plot for latitude vs. max temperature
plt.scatter(lats,
           max_temps,
           edgecolor='black', linewidths=1, marker = 'o',
           alpha=0.8, label='Cities')
#Incorporate the other graph properties
plt.title(f'City Latitude vs. Max Temperature '+ time.strftime('%x'))
plt.ylabel ('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig1.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. humidity
plt.scatter(lats,
           humidity,
           edgecolor='black', linewidths=1, marker = 'o',
           alpha=0.8, label='Cities')
#Incorporate the other graph properties
plt.title(f'City Latitude vs. Humidity '+ time.strftime('%x'))
plt.ylabel ('Humidity (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig2.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. cloudiness
plt.scatter(lats,
            cloudiness,
           edgecolor='black', linewidths=1, marker = 'o',
           alpha=0.8, label='Cities')
#Incorporate the other graph properties
plt.title(f'City Latitude vs. Cloudiness'+ time.strftime('%x'))
plt.ylabel ('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig3.png')

#Show plot
plt.show()

# %%
#Build the scatter plot for latitude vs. wind speed
plt.scatter(lats,
           wind_speed,
           edgecolor='black', linewidths=1, marker = 'o',
           alpha=0.8, label='Cities')
#Incorporate the other graph properties
plt.title(f'City Latitude vs. Wind Speed '+ time.strftime('%x'))
plt.ylabel ('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid(True)

#Save the figure
plt.savefig('weather_data/Fig4.png')

#Show plot
plt.show()

# %%
from scipy.stats import linregress
#Latitude vs. MAx temp
#perform linear regresson
(slope, intercept, r_value, p_value, std_err) = linregress(lats, max_temps)

#Calculate the regression line 'y values' from the slope and intercept
regress_values = lats * slope + intercept

#Get the equation of the line
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

#create a scatter plot of the x and y values
plt.scatter(lats, max_temps)

#Plot the regression line with the x-values and the y coordinates based on the intercept and the slope
plt.plot(lats, regress_values, 'r')

#Annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize = 15, color = 'red')
plt.title('City Latitude vs. Max temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
#Latitude vs humidity
#perform linear regresson
(slope, intercept, r_value, p_value, std_err) = linregress(lats, humidity)

#Calculate the regression line 'y values' from the slope and intercept
regress_values = lats * slope + intercept

#Get the equation of the line
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

#create a scatter plot of the x and y values
plt.scatter(lats, humidity)

#Plot the regression line with the x-values and the y coordinates based on the intercept and the slope
plt.plot(lats, regress_values, 'r')

#Annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize = 15, color = 'red')
plt.title('City Latitude vs. Humidity(%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %%
#Latitude vs cloudiness
#perform linear regresson
(slope, intercept, r_value, p_value, std_err) = linregress(lats, cloudiness)

#Calculate the regression line 'y values' from the slope and intercept
regress_values = lats * slope + intercept

#Get the equation of the line
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

#create a scatter plot of the x and y values
plt.scatter(lats, cloudiness)

#Plot the regression line with the x-values and the y coordinates based on the intercept and the slope
plt.plot(lats, regress_values, 'r')

#Annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize = 15, color = 'red')
plt.title('City Latitude vs. Cloudiness (%)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %%
#Latitude vs wind speed
#perform linear regresson
(slope, intercept, r_value, p_value, std_err) = linregress(lats, wind_speed)

#Calculate the regression line 'y values' from the slope and intercept
regress_values = lats * slope + intercept

#Get the equation of the line
line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept, 2))

#create a scatter plot of the x and y values
plt.scatter(lats, wind_speed)

#Plot the regression line with the x-values and the y coordinates based on the intercept and the slope
plt.plot(lats, regress_values, 'r')

#Annotate the text for the line equation and add its coordinates
plt.annotate(line_eq, (10,40), fontsize = 15, color = 'red')
plt.title('City Latitude vs. Wind Speed (mph)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %%
#Create a function to create perform linear regression on the weather data
#And plot a regression line and the equatin with the data
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    #Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #Calculate the regression line 'y values' from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    #Get the equation of the line
    line_eq = 'y = ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2))
    
    #Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, 'r')
    
    #Annotate the text for the line equation
    
    plt.annotate(line_eq, text_coordinates, fontsize = 15, color = 'red')
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                      Qinzhou
# Country                        CN
# Date          2022-02-03 18:06:37
# Lat                         21.95
# Lng                      108.6167
# Max Temp                    50.43
# Humidity                       77
# Cloudiness                     26
# Wind Speed                   9.42
# Name: 13, dtype: object

# %%
#Create northern and southern hemisphere DAtaFrames.
northern_hemi_df = city_data_df.loc[(city_data_df['Lat']>=0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat']<0)]

# %%
#Linear regression on the Northern hemisphere max temp
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
text_coordinates = (0,-20)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere for Maximum Temperature', 
                      'Max Temp', text_coordinates)

# %%
#Linear regression on the southern hemisphere max temp
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
text_coordinates = (-30,50)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere for Maximum Temperature', 
                      'Max Temp', text_coordinates)

# %%
#Linear regression on the northern hemisphere humidity
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
text_coordinates = (40,20)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere for Humidity', 
                      'Humidity (%)', text_coordinates)

# %%
#Linear regression on the southern hemisphere humidity
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
text_coordinates = (-30,25)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere for Humidity', 
                      'Humidity (%)', text_coordinates)

# %%
#Linear regression on the northern hemisphere cloudiness
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
text_coordinates = (40,20)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere for Cloudiness', 
                      'Cloudiness (%)', text_coordinates)

# %%
#Linear regression on the southern hemisphere cloudiness
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
text_coordinates = (-30,25)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere for Humidity', 
                      'Cloudiness (%)', text_coordinates)

# %%
#Linear regression on the northern hemisphere wind speed
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
text_coordinates = (0,40)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere for Wind Speed', 
                      'Wind Speed (mph)', text_coordinates)

# %%
#Linear regression on the southern hemisphere wind speed
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
text_coordinates = (-55,35)

#Call the function
plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Southern Hemisphere for Wind Speed', 
                      'Wind Speed (mph)', text_coordinates)
